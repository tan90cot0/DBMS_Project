# %%
import pandas as pd

# %%
df = pd.read_csv('Country.csv')

# %%
df
# Out:
#     country_code  population  life_expectancy  hospital_beds_per_thousand  \
# 0            ABW    106459.0            76.29                         NaN
# 1            AFG  41128772.0            64.83                        0.50
# 2            AGO  35588996.0            61.15                         NaN
# 3            AIA     15877.0            81.88                         NaN
# 4            ALB   2842318.0            78.57                        2.89
# ..           ...         ...              ...                         ...
# 232          WSM    222390.0            73.32                         NaN
# 233          YEM  33696612.0            66.12                        0.70
# 234          ZAF  59893884.0            64.13                        2.32
# 235          ZMB  20017670.0            63.89                        2.00
# 236          ZWE  16320539.0            61.49                        1.70
#
#      handwashing_facilities  male_smokers  female_smokers  \
# ...

# %%
df = df.fillna(0)

# %%
df.max(axis = 0)
# Out:
# country_code                           ZWE
# population                    1425887360.0
# life_expectancy                      86.75
# hospital_beds_per_thousand            13.8
# handwashing_facilities               100.0
# male_smokers                          78.1
# female_smokers                        44.0
# diabetes_prevalence                  30.53
# cardiovasc_death_rate              724.417
# extreme_poverty                       77.6
# gdp_per_capita                    116935.6
# aged_70_older                       18.493
# aged_65_older                       27.049
# median_age                            48.2
# population_density               20546.766
# stringency_index                     100.0
# dtype: object

# %%
df.to_csv("Country.csv")

# %%
df
# Out:
#     country_code  population  life_expectancy  hospital_beds_per_thousand  \
# 0            ABW    106459.0            76.29                         NaN
# 1            AFG  41128772.0            64.83                        0.50
# 2            AGO  35588996.0            61.15                         NaN
# 3            AIA     15877.0            81.88                         NaN
# 4            ALB   2842318.0            78.57                        2.89
# ..           ...         ...              ...                         ...
# 232          WSM    222390.0            73.32                         NaN
# 233          YEM  33696612.0            66.12                        0.70
# 234          ZAF  59893884.0            64.13                        2.32
# 235          ZMB  20017670.0            63.89                        2.00
# 236          ZWE  16320539.0            61.49                        1.70
#
#      handwashing_facilities  male_smokers  female_smokers  \
# ...
